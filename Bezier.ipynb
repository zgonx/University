# %%
import numpy as np
import matplotlib.pyplot as plt
def Newton( n, k ):
 
    val = 1
    for i in range( 1, k+1 ):
        val = val * ( n - i + 1 ) / i
    return val

def Bernstein(n, i, t):
    B=Newton(n, i)*(t**i)*((1.0-t)**(n-i))
    return B

def pBezier(points):
    data=[]
    data.append([])
    data.append([])
    n = len(points)-1
    ll = 100
    for i in range( ll+1):
        t=i/ll
        
        px=0
        py=0
        for j in range(n+1):
            bb=Bernstein(n, j,t)
            #print(bb)
            px+=points[j][0]*bb
            py+=points[j][1]*bb
        print(px, py)
        data[0].append(px)
        data[1].append(py)        
    return data

# %%
data=pBezier([[0,40],[0, 0], [200,50], [-150,100], [50, 200],[45,150]])
# data2=pBezier([[0,40],[0,0],[100,50],[-70,100],[10,100],[60,100],[0,150],[0,125]])
# data2=pBezier([[40,40],[0,0],[0,40],[]])
#data=np.ones((500,500,3))
a=plt.plot(data[0], data[1])
# b=plt.plot(data2[0], data2[1])

plt.show()
# Out:
# 0.0 40.0
# 0.19259212950000004 38.08910696099999
# 0.741468144 36.352910752
# 1.6049024685 34.786257522999996
# 2.7433006079999993 33.38415206399999
# 4.119154687500001 32.141753124999994
# 5.696998991999999 31.054368735999994
# 7.4433655065 30.117451526999993
# 9.326739456 29.326594048000004
# 11.317514845500002 28.677524089000006
# 13.387950000000005 28.1661
# 15.5121231045 27.788306011
# 17.665887744 27.540247552
# 19.8268284435 27.418146573
# 21.974216208000005 27.418336863999997
# 24.08896406249999 27.537259374999994
# 26.153582591999992 27.771457535999996
# 28.152135481499997 28.117572576999997
# 30.070195056000003 28.57233884800001
# 31.894797820500003 29.132579139000008
# 33.61440000000002 29.795200000000012
# 35.2188330795 30.557187061
# 36.699259344000005 31.415600352000006
# 38.0481274185 32.367569623
# 39.259127808 33.410289664
# 40.3271484375 34.541015625
# 41.248230191999994 35.757058336
# 42.0195224565 37.055779627
# 42.63923865600002 38.434587648000004
# ...

# %%
data2=pBezier([[0,40],[0,0],[100,50],[-70,100],[10,100],[60,100],[0,150],[0,125]])
b=plt.plot(data2[0], data2[1])
plt.show()

[[0,40],[0, 0], [200,50], [-150,100], [50, 200],[45,150]])
# Out:
# 0.0 40.0
# 0.1973579697936 37.38586412488085
# 0.7412716324608 35.13102796042879
# 1.5647327404631997 33.21711380337894
# 2.6073863553024 31.6261084504064
# 3.8151382499999995 30.34037631640624
# 5.139775318809598 29.342671759225592
# 6.5385988107048 28.616150615131538
# 7.974070203187203 28.14438094929921
# 9.413469532958404 27.911353025603656
# 10.828566000000004 27.901488500000006
# 12.195300661605602 28.099648841775355
# 13.493481032908798 28.491142986956802
# 14.706487410451201 29.06173422815945
# 15.820990735334401 29.7976463451584
# 16.8266818125 30.685568980468748
# 17.716011702681598 31.712662264217595
# 18.4839431035728 32.866560692592046
# 19.127712536755208 34.135376264147226
# 19.646603156930404 35.50770087825816
# 20.04172800000001 36.972608000000015
# 20.3158234865376 38.51965359573985
# 20.4730529971968 40.1388763437248
# 20.5188203365992 41.82079712394996
# 20.459592902246406 43.556417791590405
# 20.302734375 45.33721923828125
# 20.056346747673597 47.1551587455296
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches

verts = [
    (0.2, 0.1),  # P0
    (0.5, 0.0), # P1
    (0.5, 0.5), # P2
    (0.2, 0.6), # P3
    (0.2, 0.6),
    (0.5, 1.0),
    (0.1, 1.0),
#     (0.5, 0.9),

    ]

codes = [Path.MOVETO,
         Path.CURVE4,
         Path.CURVE4,
         Path.CURVE4,
         Path.CURVE4,
         Path.CURVE4,
         Path.CURVE4,
#          Path.CURVE4,
         
         ]

path = Path(verts, codes)

fig = plt.figure()
ax = fig.add_subplot(111)
patch = patches.PathPatch(path, facecolor='none', lw=2)
ax.add_patch(patch)
